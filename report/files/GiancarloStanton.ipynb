# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import math

x = (1, 2, 3, 4, 5, 6)
index = np.arange(len(x))
y = [449, 425, 539, 279, 413, 597]

preAvgAB = math.floor((y[0] + y[1] + y[2])/3)
postAvgAB = math.floor((y[3] + y[4] + y[5])/3)
percentChangeAB = float((postAvgAB/preAvgAB - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('At-Bats')
plt.title('Giancarlo Stanton At-Bats')
plt.show()

print('Average at-bats pre contract = %.0f' % preAvgAB)
print('Average at-bats post contract = %.0f' % postAvgAB)
print('Percent change = %.1f' % percentChangeAB  + '%\n\n')

###############################################################################

y = [123, 116, 145, 74, 119, 159]

preAvgGP = math.floor((y[0] + y[1] + y[2])/3)
postAvgGP = math.floor((y[3] + y[4] + y[5])/3)
percentChangeGP = float((postAvgGP/preAvgGP - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Games Played')
plt.title('Giancarlo Stanton Games Played')
plt.show()

print('Average Games Played pre contract = %.0f' % preAvgGP)
print('Average Games Glayed post contract = %.0f' % postAvgGP)
print('Percent change = %.1f' % percentChangeGP + '%\n\n')

###############################################################################

y = [130, 106, 155, 74, 99, 168]

preAvgH = math.floor((y[0] + y[1] + y[2])/3)
postAvgH = math.floor((y[3] + y[4] + y[5])/3)
percentChangeH = float((postAvgH/preAvgH - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Hits')
plt.title('Giancarlo Stanton Hits')
plt.show()

print('Average Hits pre contract = %.0f' % preAvgH)
print('Average Hits post contract = %.0f' % postAvgH)
print('Percent change = %.1f' % percentChangeH + '%\n\n')

###############################################################################

y = [30, 26, 31, 12, 20, 32]

preAvgD = math.floor((y[0] + y[1] + y[2])/3)
postAvgD = math.floor((y[3] + y[4] + y[5])/3)
percentChangeD = float((postAvgD/preAvgD - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Doubles')
plt.title('Giancarlo Stanton Doubles')
plt.show()

print('Average Doubles pre contract = %.0f' % preAvgD)
print('Average Doubles post contract = %.0f' % postAvgD)
print('Percent change = %.1f' % percentChangeD + '%\n\n')

###############################################################################

y = [1, 0, 1, 1, 1, 0]

#preAvgT = math.floor((y[0] + y[1] + y[2])/3)
#postAvgT = math.floor((y[3] + y[4] + y[5])/3)
preAvgT = 1
postAvgT = 1
percentChangeT = float((postAvgT/preAvgT - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Triples')
plt.title('Giancarlo Stanton Triples')
plt.show()

print('Average Triples pre contract = %.0f' % preAvgT)
print('Average Triples post contract = %.0f' % postAvgT)
print('Percent change = %.1f' % percentChangeT + '%\n\n')

###############################################################################

y = [37, 24, 37, 27, 27, 59]

preAvgHR = math.floor((y[0] + y[1] + y[2])/3)
postAvgHR = math.floor((y[3] + y[4] + y[5])/3)
percentChangeHR = float((postAvgHR/preAvgHR - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Home Runs')
plt.title('Giancarlo Stanton Home Runs')
plt.show()

print('Average Home Runs pre contract = %.0f' % preAvgHR)
print('Average Home Runs post contract = %.0f' % postAvgHR)
print('Percent change = %.1f' % percentChangeHR + '%\n\n')

###############################################################################

y = [86, 62, 105, 67, 74, 132]

preAvgRBI = math.floor((y[0] + y[1] + y[2])/3)
postAvgRBI = math.floor((y[3] + y[4] + y[5])/3)
percentChangeRBI = float((postAvgRBI/preAvgRBI - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('RBI\'s')
plt.title('Giancarlo Stanton RBI\'s')
plt.show()

print('Average RBI\'s pre contract = %.0f' % preAvgRBI)
print('Average RBI\'s post contract = %.0f' % postAvgRBI)
print('Percent change = %.1f' % percentChangeRBI + '%\n\n')

###############################################################################

y = [46, 74, 94, 34, 50, 85]

preAvgBB = math.floor((y[0] + y[1] + y[2])/3)
postAvgBB = math.floor((y[3] + y[4] + y[5])/3)
percentChangeBB = float((postAvgBB/preAvgBB - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Walks')
plt.title('Giancarlo Stanton Walks')
plt.show()

print('Average Walks pre contract = %.0f' % preAvgBB)
print('Average Walks post contract = %.0f' % postAvgBB)
print('Percent change = %.1f' % percentChangeBB + '%\n\n')

###############################################################################

y = [143, 140, 170, 95, 140, 163]

preAvgK = math.floor((y[0] + y[1] + y[2])/3)
postAvgK = math.floor((y[3] + y[4] + y[5])/3)
percentChangeK = float((postAvgK/preAvgK - 1.0)*-100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Strikeouts')
plt.title('Giancarlo Stanton Strikeouts')
plt.show()

print('Average Strikeouts pre contract = %.0f' % preAvgK)
print('Average Strikeouts post contract = %.0f' % postAvgK)
print('Percent change = %.1f' % percentChangeK + '%\n\n')

###############################################################################

y = [290, 249, 288, 265, 240, 281]

preAvgBA = math.floor((y[0] + y[1] + y[2])/3)
postAvgBA = math.floor((y[3] + y[4] + y[5])/3)
percentChangeBA = float((postAvgBA/preAvgBA - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('Batting Average *1000')
plt.title('Giancarlo Stanton Batting Average')
plt.show()

print('Average Batting Average pre contract = .%.0f' % preAvgBA)
print('Average Batting Average post contract = .%.0f' % postAvgBA)
print('Percent change = %.1f' % percentChangeBA + '%\n\n')

###############################################################################

y = [361, 365, 395, 346, 326, 376]

preAvgOBP = math.floor((y[0] + y[1] + y[2])/3)
postAvgOBP = math.floor((y[3] + y[4] + y[5])/3)
percentChangeOBP = float((postAvgOBP/preAvgOBP - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('OBP *1000')
plt.title('Giancarlo Stanton OBP')
plt.show()

print('Average OBP pre contract = .%.0f' % preAvgOBP)
print('Average OBP post contract = .%.0f' % postAvgOBP)
print('Percent change = %.1f' % percentChangeOBP + '%\n\n')

###############################################################################

y = [608, 480, 555, 606, 489, 631]

preAvgSLG = math.floor((y[0] + y[1] + y[2])/3)
postAvgSLG = math.floor((y[3] + y[4] + y[5])/3)
percentChangeSLG = float((postAvgSLG/preAvgSLG - 1.0)*100.0)

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Year\n\n(1-3 Represent Pre Contract & 4-6 Represent Post Contract)')
plt.ylabel('SLG% *1000')
plt.title('Giancarlo Stanton SLG%')
plt.show()

print('Average SLG pre contract = .%.0f' % preAvgSLG)
print('Average SLG post contract = .%.0f' % postAvgSLG)
print('Percent change = %.1f' % percentChangeSLG + '%\n')

totalAvg = float((percentChangeAB + percentChangeBA + percentChangeBB + 
                  percentChangeD + percentChangeGP + percentChangeH +
                  percentChangeHR + percentChangeK + percentChangeOBP +
                  percentChangeRBI + percentChangeSLG + percentChangeT)/12.0)

print('Average of all percentage changes = %.1f' % totalAvg + "%\n")

###############################################################################

print('SALARY COMPARISON BETWEEN PLAYER SALARY AND TEAM PAYROLL\n')

def calc(playerSalary, teamSalary, year):
  
  player = "${:,}".format(playerSalary)
  team = "${:,}".format(teamSalary)
  percentOfPayroll = float(playerSalary/teamSalary)*100.0

  print('YEAR ' + str(year))
  print("Giancarlo Stanton's Salary = " + player)
  print('Team Payroll = ' + team)
  print('Percent of Payroll = %.1f' % percentOfPayroll + '%\n')
  
  return percentOfPayroll

x = (1, 2, 3)
index = np.arange(len(x))
y = [calc(25000000, 84637500, x[0]), calc(25000000, 70464500, x[1]), calc(25000000, 115348302, x[2])]

plt.bar(index, y)
plt.xticks(index, x)
plt.xlabel('Years Post Contract')
plt.ylabel('% of Team Salary')
plt.title('Giancarlo Stanton % of Team Salary')
plt.show()
# Out:
# Average at-bats pre contract = 471
# Average at-bats post contract = 429
# Percent change = -8.9%
# Average Games Played pre contract = 128
# Average Games Glayed post contract = 117
# Percent change = -8.6%
# Average Hits pre contract = 130
# Average Hits post contract = 113
# Percent change = -13.1%
# Average Doubles pre contract = 29
# Average Doubles post contract = 21
# Percent change = -27.6%
# Average Triples pre contract = 1
# Average Triples post contract = 1
# Percent change = 0.0%
# Average Home Runs pre contract = 32
# Average Home Runs post contract = 37
# Percent change = 15.6%
# Average RBI's pre contract = 84
# Average RBI's post contract = 91
# Percent change = 8.3%
# Average Walks pre contract = 71
# Average Walks post contract = 56
# Percent change = -21.1%
# Average Strikeouts pre contract = 151
# Average Strikeouts post contract = 132
# Percent change = 12.6%
# Average Batting Average pre contract = .275
# Average Batting Average post contract = .262
# ...
